# %%
import pandas as pd
df_init = pd.read_csv("master.csv")
df_HDI = pd.read_csv("Human development index (HDI).csv")

# %%
df_init.shape
# Out:
# (27820, 12)

# %%
df_HDI.shape
# Out:
# (190, 1)

# %%
for x,y in df_HDI.iterrows():
    print(x,y)
# Out:
# (('HDI Rank (2017)', 'Country', 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0), Human development index (HDI)    2017.0
# Name: (HDI Rank (2017), Country, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0), dtype: float64)
# (('168', ' Afghanistan', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 0.373, 0.38299999999999995, 0.39799999999999996, 0.408, 0.41700000000000004, 0.429, 0.43700000000000006, 0.45299999999999996, 0.46299999999999997, 0.47100000000000003, 0.48200000000000004, 0.48700000000000004, 0.491, 0.493, 0.494), Human development index (HDI)    0.498
# ...
